# %%
pip install opencv-python numpy torch torchvision sort
# Out:
# ...
#                                               0.0/38.6 MB ? eta -:--:--
#                                              0.1/38.6 MB 871.5 kB/s eta 0:00:45
#                                               0.2/38.6 MB 2.4 MB/s eta 0:00:17
#                                               0.3/38.6 MB 2.5 MB/s eta 0:00:16
#                                               0.4/38.6 MB 2.1 MB/s eta 0:00:19
#                                               0.6/38.6 MB 2.3 MB/s eta 0:00:17
#                                               0.9/38.6 MB 3.3 MB/s eta 0:00:12
#      -                                        1.2/38.6 MB 3.8 MB/s eta 0:00:10
#      -                                        1.5/38.6 MB 4.0 MB/s eta 0:00:10
#      -                                        1.6/38.6 MB 3.8 MB/s eta 0:00:10
#      -                                        1.8/38.6 MB 3.9 MB/s eta 0:00:10
#      --                                       2.2/38.6 MB 4.2 MB/s eta 0:00:09
# ...

# %%
git clone https://github.com/abewley/sort.git
# Out:
#   Cell In[2], line 1
#     git clone https://github.com/abewley/sort.git
#         ^
# SyntaxError: invalid syntax
